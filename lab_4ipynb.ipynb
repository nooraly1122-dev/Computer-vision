# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
image_path = '/content/xray.jpg'
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
negative = 255 - img

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(negative, cmap='gray')
plt.title("Negative Image")
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Save the current Colab notebook and upload it to a GitHub repository.

# %% [markdown]
# ## Save Notebook
#
# ### Subtask:
# Save the current Colab notebook as an .ipynb file.

# %% [markdown]
# ### Subtask
# Save the current Colab notebook as an .ipynb file.
#
# #### Instructions
# To save the current Colab notebook, navigate to 'File' in the top menu, then select 'Save a copy in GitHub' or 'Save a copy to Drive' if you prefer to save locally first, and finally download it as an .ipynb file if saved to Drive.

# %% [markdown]
# ## Authenticate GitHub
#
# ### Subtask:
# Provide instructions to authenticate with GitHub for subsequent actions.

# %% [markdown]
# ### Subtask
# Provide instructions to authenticate with GitHub for subsequent actions.
#
# #### Instructions
# 1. Go to your GitHub profile settings.
# 2. Navigate to 'Developer settings' and then 'Personal access tokens'.
# 3. Generate a new token with appropriate repository permissions (e.g., 'repo' scope).
# 4. Copy the generated token.
# 5. In Colab, go to 'Secrets' (key icon on the left sidebar).
# 6. Click 'Add new secret'.
# 7. Set the 'Name' as 'GH_TOKEN' and paste your GitHub personal access token into the 'Value' field. Ensure 'Notebook access' is enabled for this secret.

# %% [markdown]
# ### Subtask
# Provide instructions to authenticate with GitHub for subsequent actions.
#
# #### Instructions
# 1. Go to your GitHub profile settings.
# 2. Navigate to 'Developer settings' and then 'Personal access tokens'.
# 3. Generate a new token with appropriate repository permissions (e.g., 'repo' scope).
# 4. Copy the generated token.
# 5. In Colab, go to 'Secrets' (key icon on the left sidebar).
# 6. Click 'Add new secret'.
# 7. Set the 'Name' as 'GH_TOKEN' and paste your GitHub personal access token into the 'Value' field. Ensure 'Notebook access' is enabled for this secret.
# 8. Access the token in a Python code block using `from google.colab import userdata; GH_TOKEN = userdata.get('GH_TOKEN')`.

# %% [markdown]
# ### Subtask
# Provide instructions to authenticate with GitHub for subsequent actions.
#
# #### Instructions
# 1. Go to your GitHub profile settings.
# 2. Navigate to 'Developer settings' and then 'Personal access tokens'.
# 3. Generate a new token with appropriate repository permissions (e.g., 'repo' scope).
# 4. Copy the generated token.
# 5. In Colab, go to 'Secrets' (key icon on the left sidebar).
# 6. Click 'Add new secret'.
# 7. Set the 'Name' as 'GH_TOKEN' and paste your GitHub personal access token into the 'Value' field. Ensure 'Notebook access' is enabled for this secret.
# 8. Access the token in a Python code block using `from google.colab import userdata; GH_TOKEN = userdata.get('GH_TOKEN')`.

# %% [markdown]
# ### Subtask
# Provide instructions to authenticate with GitHub for subsequent actions.
#
# #### Instructions
# 1. Go to your GitHub profile settings.
# 2. Navigate to 'Developer settings' and then 'Personal access tokens'.
# 3. Generate a new token with appropriate repository permissions (e.g., 'repo' scope).
# 4. Copy the generated token.
# 5. In Colab, go to 'Secrets' (key icon on the left sidebar).
# 6. Click 'Add new secret'.
# 7. Set the 'Name' as 'GH_TOKEN' and paste your GitHub personal access token into the 'Value' field. Ensure 'Notebook access' is enabled for this secret.
# 8. Access the token in a Python code block using `from google.colab import userdata; GH_TOKEN = userdata.get('GH_TOKEN')`.

# %% [markdown]
# ### Subtask
# Provide instructions to authenticate with GitHub for subsequent actions.
#
# #### Instructions
# 1. Go to your GitHub profile settings.
# 2. Navigate to 'Developer settings' and then 'Personal access tokens'.
# 3. Generate a new token with appropriate repository permissions (e.g., 'repo' scope).
# 4. Copy the generated token.
# 5. In Colab, go to 'Secrets' (key icon on the left sidebar).
# 6. Click 'Add new secret'.
# 7. Set the 'Name' as 'GH_TOKEN' and paste your GitHub personal access token into the 'Value' field. Ensure 'Notebook access' is enabled for this secret.
# 8. Access the token in a Python code block using `from google.colab import userdata; GH_TOKEN = userdata.get('GH_TOKEN')`.

# %% [markdown]
# ## Upload to GitHub Repository
#
# ### Subtask:
# Generate code to upload the saved notebook to a specified GitHub repository.

# %% [markdown]
# First, you need to set up your GitHub Personal Access Token (GH_TOKEN) as a Colab Secret. This token will be used to authenticate with GitHub and upload the notebook. Follow these steps:
#
# 1.  **Generate a GitHub Personal Access Token:**
#     *   Go to your GitHub account settings.
#     *   Navigate to `Developer settings` > `Personal access tokens` > `Tokens (classic)`.
#     *   Click on `Generate new token` (or `Generate new token (classic)`).
#     *   Give your token a descriptive name (e.g., `colab_github_upload`).
#     *   Grant the token the `repo` scope (full control of private repositories) to allow pushing to your repository.
#     *   Click `Generate token` and copy the generated token. **Keep it safe, as you won't be able to see it again.**
#
# 2.  **Add the Token to Colab Secrets:**
#     *   In your Colab notebook, click on the 'Secrets' icon (a key icon) in the left sidebar.
#     *   Click on `+ New secret`.
#     *   For the 'Name' field, type `GH_TOKEN`.
#     *   For the 'Value' field, paste your GitHub Personal Access Token.
#     *   Ensure the 'Notebook access' toggle is ON for this notebook.
#
# Once `GH_TOKEN` is set up in Colab Secrets, the following code will be able to access it securely.

# %% [markdown]
# **Reasoning**:
# The next step is to define the required GitHub and file path variables and retrieve the GH_TOKEN from Colab Secrets to prepare for Git operations.

# %%
from google.colab import userdata

# 1. Define variables for your GitHub username, repository name, branch name, and the local path to your saved notebook file.
# IMPORTANT: Replace these with your actual GitHub username, repository name, and desired branch.
github_username = "your_github_username"  # e.g., "octocat"
repo_name = "your_repository_name"      # e.g., "my-colab-notebooks"
branch_name = "main"                     # e.g., "main" or "master"

# This assumes your current notebook will be saved as 'current_notebook.ipynb' in the root of the Colab environment.
# If your notebook is saved elsewhere, update this path.
notebook_file_path = "/content/xray_image_processing.ipynb" # Example: 'my_project_notebook.ipynb'

# 2. Set up the Git credentials using your GH_TOKEN (retrieved from Colab Secrets)
# Ensure GH_TOKEN is set in Colab secrets as per the previous instructions.
GH_TOKEN = userdata.get('GH_TOKEN')

print("GitHub variables defined and token retrieved (not displayed for security).")
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_375/1457858542.py in <cell line: 0>()
#      13 # 2. Set up the Git credentials using your GH_TOKEN (retrieved from Colab Secrets)
#      14 # Ensure GH_TOKEN is set in Colab secrets as per the previous instructions.
# ---> 15 GH_TOKEN = userdata.get('GH_TOKEN')
#      16
#      17 print("GitHub variables defined and token retrieved (not displayed for security).")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GH_TOKEN does not exist.

# %% [markdown]
# **Reasoning**:
# The previous code failed because the 'GH_TOKEN' was not found in Colab Secrets. I will modify the code to include error handling for `SecretNotFoundError`, providing clear instructions to the user on how to set up the secret if it's missing, making the code more robust and user-friendly.

# %%
from google.colab import userdata
from google.colab.userdata import SecretNotFoundError

# 1. Define variables for your GitHub username, repository name, branch name, and the local path to your saved notebook file.
# IMPORTANT: Replace these with your actual GitHub username, repository name, and desired branch.
github_username = "your_github_username"  # e.g., "octocat"
repo_name = "your_repository_name"      # e.g., "my-colab-notebooks"
branch_name = "main"                     # e.g., "main" or "master"

# This assumes your current notebook will be saved as 'current_notebook.ipynb' in the root of the Colab environment.
# If your notebook is saved elsewhere, update this path.
notebook_file_path = "/content/xray_image_processing.ipynb" # Example: 'my_project_notebook.ipynb'

# 2. Set up the Git credentials using your GH_TOKEN (retrieved from Colab Secrets)
# Ensure GH_TOKEN is set in Colab secrets as per the previous instructions.
try:
    GH_TOKEN = userdata.get('GH_TOKEN')
    print("GitHub variables defined and token retrieved (not displayed for security).")
except SecretNotFoundError:
    print("Error: GH_TOKEN not found in Colab Secrets.")
    print("Please ensure your GitHub Personal Access Token is correctly set as 'GH_TOKEN' in Colab Secrets.")
    print("Instructions:\n1. Click on the 'Secrets' icon (key icon) in the left sidebar.\n2. Click '+ New secret'.\n3. Set 'Name' as 'GH_TOKEN' and paste your GitHub PAT into 'Value'.\n4. Ensure 'Notebook access' is enabled for this notebook.")
    GH_TOKEN = None # Set to None to prevent further errors if the token is critical for subsequent steps
# Out:
# Error: GH_TOKEN not found in Colab Secrets.
# Please ensure your GitHub Personal Access Token is correctly set as 'GH_TOKEN' in Colab Secrets.
# Instructions:
# 1. Click on the 'Secrets' icon (key icon) in the left sidebar.
# 2. Click '+ New secret'.
# 3. Set 'Name' as 'GH_TOKEN' and paste your GitHub PAT into 'Value'.
# 4. Ensure 'Notebook access' is enabled for this notebook.
